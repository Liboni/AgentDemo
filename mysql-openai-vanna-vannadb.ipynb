# %% [markdown]
# # Generating SQL for MySQL using OpenAI via Vanna.AI (Recommended), Vanna Hosted Vector DB (Recommended)
# This notebook runs through the process of using the `vanna` Python package to generate SQL using AI (RAG + LLMs) including connecting to a database and training. If you're not ready to train on your own database, you can still try it using a sample [SQLite database](app.md).

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which LLM do you want to use?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> OpenAI via Vanna.AI (Recommended)</div>
#         <small class="w-full">Use Vanna.AI for free to generate your queries</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-standard-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">OpenAI</div>
#         <small class="w-full">Use OpenAI with your own API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-azure-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Azure OpenAI</div>
#         <small class="w-full">If you have OpenAI models deployed on Azure</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-anthropic-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Anthropic</div>
#         <small class="w-full">Use Anthropics Claude with your Anthropic API Key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-ollama-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Ollama</div>
#         <small class="w-full">Use Ollama locally for free. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-gemini-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Google Gemini</div>
#         <small class="w-full">Use Google Gemini with your Gemini or Vertex API Key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-mistral-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Mistral via Mistral API</div>
#         <small class="w-full">If you have a Mistral API key</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-other-llm-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other LLM</div>
#         <small class="w-full">If you have a different LLM model</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Where do you want to store the 'training' data?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> Vanna Hosted Vector DB (Recommended)</div>
#         <small class="w-full">Use Vanna.AIs hosted vector database (pgvector) for free. This is usable across machines with no additional setup.</small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-standard-chromadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">ChromaDB</div>
#         <small class="w-full">Use ChromaDBs open-source vector database for free locally. No additional setup is necessary -- all database files will be created and stored locally.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-standard-qdrant/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Qdrant</div>
#         <small class="w-full">Use Qdrants open-source vector database</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-standard-marqo/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Marqo</div>
#         <small class="w-full">Use Marqo locally for free. Requires additional setup. Or use their hosted option.</small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mysql-openai-standard-other-vectordb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other VectorDB</div>
#         <small class="w-full">Use any other vector database. Requires additional setup.</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %% [markdown]
# ## Setup

# %%
# %pip install 'vanna[mysql]'
# Out:
# Collecting vanna[mysql]
#   Downloading vanna-0.7.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (2.32.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (0.9.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (2.2.2)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (0.5.3)
# Collecting kaleido (from vanna[mysql])
#   Downloading kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (3.1.1)
# Collecting flask-sock (from vanna[mysql])
#   Downloading flask_sock-0.7.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting flasgger (from vanna[mysql])
#   Downloading flasgger-0.9.7.1.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from vanna[mysql]) (2.0.43)
# Collecting PyMySQL (from vanna[mysql])
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.11/dist-packages (from flasgger->vanna[mysql]) (6.0.2)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from flasgger->vanna[mysql]) (4.25.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.11/dist-packages (from flasgger->vanna[mysql]) (3.1.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from flasgger->vanna[mysql]) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from flasgger->vanna[mysql]) (25.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from flask->vanna[mysql]) (3.1.3)
# Collecting simple-websocket>=0.5.1 (from flask-sock->vanna[mysql])
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting choreographer>=1.0.5 (from kaleido->vanna[mysql])
#   Downloading choreographer-1.0.9-py3-none-any.whl.metadata (5.6 kB)
# Collecting logistro>=1.0.8 (from kaleido->vanna[mysql])
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.11/dist-packages (from kaleido->vanna[mysql]) (3.11.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->vanna[mysql]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->vanna[mysql]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->vanna[mysql]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->vanna[mysql]) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->vanna[mysql]) (9.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vanna[mysql]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vanna[mysql]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vanna[mysql]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vanna[mysql]) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->vanna[mysql]) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->vanna[mysql]) (4.14.1)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.11/dist-packages (from choreographer>=1.0.5->kaleido->vanna[mysql]) (3.20.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[mysql]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[mysql]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[mysql]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0.1->flasgger->vanna[mysql]) (0.27.0)
# Collecting wsproto (from simple-websocket>=0.5.1->flask-sock->vanna[mysql])
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.5.1->flask-sock->vanna[mysql]) (0.16.0)
# Downloading flask_sock-0.7.0-py3-none-any.whl (4.0 kB)
# Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 4.3 MB/s eta 0:00:00
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.2 MB/s eta 0:00:00
# Downloading vanna-0.7.9-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 18.9 MB/s eta 0:00:00
# Downloading choreographer-1.0.9-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 4.6 MB/s eta 0:00:00
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: flasgger
#   Building wheel for flasgger (setup.py) ... done
#   Created wheel for flasgger: filename=flasgger-0.9.7.1-py2.py3-none-any.whl size=3865185 sha256=9f610a46298a5551b27eb342eb11d0686bd80a00f70227bfd6498d655efdea66
#   Stored in directory: /root/.cache/pip/wheels/da/2d/f6/c125d4b8701ac49fdb2abbfb978036c46d5ad64d2ffaa2ac34
# Successfully built flasgger
# Installing collected packages: wsproto, PyMySQL, logistro, simple-websocket, choreographer, kaleido, flask-sock, flasgger, vanna
# Successfully installed PyMySQL-1.1.1 choreographer-1.0.9 flasgger-0.9.7.1 flask-sock-0.7.0 kaleido-1.0.0 logistro-1.1.0 simple-websocket-1.1.0 vanna-0.7.9 wsproto-1.2.0

# %%
import vanna
from vanna.remote import VannaDefault

# %%
api_key = '6c44d53c1ea64655b6cb10663c5776de'

vanna_model_name = 'medicaldemo'
vn = VannaDefault(model=vanna_model_name, api_key=api_key)

# %% [markdown]
# <h3 class="mb-5 text-lg font-medium text-gray-900 dark:text-white">Which database do you want to query?</h3>
# <ul class="grid w-full gap-6 md:grid-cols-2">
#
#   <li>
#     <a href="../postgres-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Postgres</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../mssql-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Microsoft SQL Server</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <span class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border bg-white p-5 border-blue-600 text-blue-600 dark:bg-gray-800 dark:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold"><span class="hidden">[Selected]</span> MySQL</div>
#         <small class="w-full"></small>
#       </div>
#     </span>
#   </li>
#
#   <li>
#     <a href="../duckdb-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">DuckDB</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../snowflake-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Snowflake</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../bigquery-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">BigQuery</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../sqlite-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">SQLite</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../oracle-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Oracle</div>
#         <small class="w-full"></small>
#       </div>
#     </a>
#   </li>
#
#   <li>
#     <a href="../other-database-openai-vanna-vannadb/" class="inline-flex w-full cursor-pointer items-center justify-between rounded-lg border border-gray-200 bg-white p-5 text-gray-500 hover:bg-gray-100 hover:text-gray-600 peer-checked:border-blue-600 peer-checked:text-blue-600 dark:border-gray-700 dark:bg-gray-800 dark:text-gray-400 dark:hover:bg-gray-700 dark:hover:text-gray-300 dark:peer-checked:text-blue-500">
#       <div class="block">
#         <div class="w-full text-lg font-semibold">Other Database</div>
#         <small class="w-full">Use Vanna to generate queries for any SQL database</small>
#       </div>
#     </a>
#   </li>
#
# </ul>

# %%
vn.connect_to_mysql(host='6.tcp.eu.ngrok.io', dbname='cdp', user='remote_user', password='YourSecurePassword123!', port=16792)

# %% [markdown]
# ## Training
# You only need to train once. Do not train again unless you want to add more training data.

# %%
# The information schema query may need some tweaking depending on your database. This is a good starting point.
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")

# This will break up the information schema into bite-sized chunks that can be referenced by the LLM
plan = vn.get_training_plan_generic(df_information_schema)
plan

# If you like the plan, then uncomment this and run it to train
vn.train(plan=plan)

# %%
# The following are methods for adding training data. Make sure you modify the examples to match your database.

# DDL statements are powerful because they specify table names, colume names, types, and potentially relationships
# vn.train(ddl="""
#     CREATE TABLE IF NOT EXISTS my-table (
#         id INT PRIMARY KEY,
#         name VARCHAR(100),
#         age INT
#     )
# """)

# Sometimes you may want to add documentation about your business terminology or definitions.
vn.train(documentation="Our business is a dental company which focus on patient care, wit information on doctors, which are General Dentist, Orthodontist, Oral Surgeon, Pediatric Dentist, Hygienist. And we have branches at different locations. So we track the information of the patients how much they paid and who was the doctor who served them. It also have a list of potential patients and there medical aid there are using. The company is located in USA texas")

# You can also add SQL queries to your training data. This is useful if you have some queries already laying around. You can just copy and paste those from your editor to begin generating new SQL.
vn.train(sql="SELECT * FROM cdp.ppo_details WHERE expiry > '1970-01-01 00:00:01' ORDER BY id DESC;")
vn.train(sql="SELECT * FROM cdp.mcodetails WHERE recredentialBy > '1970-01-01 00:00:01' ORDER BY id DESC;")
# Out:
# Adding documentation....
# Question generated with sql: What are the details of all active items that have not expired?
# Adding SQL...
# Question generated with sql: What are the recent records that have been recredentialed since the beginning of 1970?
# Adding SQL...
# '61e26d816ac671cb9684541f3d63caaf-sql'

# %%
# At any time you can inspect what training data the package is able to reference
training_data = vn.get_training_data()
training_data
# Out:
#               id training_data_type question  \
# 0    3446293-doc      documentation     None
# 1    3446273-doc      documentation     None
# 2    3446136-doc      documentation     None
# 3    3446173-doc      documentation     None
# 4    3446093-doc      documentation     None
# ..           ...                ...      ...
# 365  3446354-doc      documentation     None
# 366  3446331-doc      documentation     None
# 367  3446257-doc      documentation     None
# 368  3446251-doc      documentation     None
# 369  3446062-doc      documentation     None
#
#                                                content
# 0    The following columns are in the udaadjcodes t...
# 1    The following columns are in the site_data tab...
# 2    The following columns are in the commlogsearch...
# 3    The following columns are in the hygienistbrac...
# 4    The following columns are in the INNODB_FT_IND...
# ..                                                 ...
# 365  The following columns are in the ukguser table...
# 366  The following columns are in the websites_stat...
# 367  The following columns are in the recruit_user_...
# 368  The following columns are in the recruit_insig...
# 369  The following columns are in the PROCESSLIST t...
#
# [370 rows x 4 columns]

# %%
# You can remove training data if there's obsolete/incorrect information.
# vn.remove_training_data(id='1-ddl')
vn.allow_llm_to_see_data=True

# %% [markdown]
# ## Asking the AI
# Whenever you ask a new question, it will find the 10 most relevant pieces of training data and use it as part of the LLM prompt to generate the SQL.

# %%
vn.ask(question="may you list doctor types", allow_llm_to_see_data=True)
# Out:
# SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Additional Context \n\nOur business is a dental company which focus on patient care, wit information on doctors, which are General Dentist, Orthodontist, Oral Surgeon, Pediatric Dentist, Hygienist. And we have branches at different locations. So we track the information of the patients how much they paid and who was the doctor who served them. It also have a list of potential patients and there medical aid there are using. The company is located in USA texas\n\nThe following columns are in the doctors table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME   | COLUMN_NAME           | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:-------------|:----------------------|:------------|:-----------------|\n| 3811 | def             | cdp            | doctors      | abbr                  | varchar     |                  |\n| 3812 | def             | cdp            | doctors      | address               | varchar     |                  |\n| 3813 | def             | cdp            | doctors      | canManage             | varchar     |                  |\n| 3814 | def             | cdp            | doctors      | canWork               | varchar     |                  |\n| 3815 | def             | cdp            | doctors      | contractEnd           | varchar     |                  |\n| 3816 | def             | cdp            | doctors      | contractStart         | varchar     |                  |\n| 3817 | def             | cdp            | doctors      | createdAt             | datetime    |                  |\n| 3818 | def             | cdp            | doctors      | createdBy             | int         |                  |\n| 3819 | def             | cdp            | doctors      | credentialingDocs     | tinyint     |                  |\n| 3820 | def             | cdp            | doctors      | dateOfBirth           | datetime    |                  |\n| 3821 | def             | cdp            | doctors      | defaultPage           | varchar     |                  |\n| 3822 | def             | cdp            | doctors      | dentistShiftSpecialty | varchar     |                  |\n| 3823 | def             | cdp            | doctors      | dentistShiftType      | varchar     |                  |\n| 3824 | def             | cdp            | doctors      | dentistSubType        | varchar     |                  |\n| 3825 | def             | cdp            | doctors      | dentistType           | varchar     |                  |\n| 3826 | def             | cdp            | doctors      | dentistWorkTimeType   | varchar     |                  |\n| 3827 | def             | cdp            | doctors      | docEmail              | varchar     |                  |\n| 3828 | def             | cdp            | doctors      | docMobile             | varchar     |                  |\n| 3829 | def             | cdp            | doctors      | firstName             | varchar     |                  |\n| 3830 | def             | cdp            | doctors      | gender                | varchar     |                  |\n| 3831 | def             | cdp            | doctors      | hideUsage             | tinyint     |                  |\n| 3832 | def             | cdp            | doctors      | hireDate              | varchar     |                  |\n| 3833 | def             | cdp            | doctors      | homeLocation          | varchar     |                  |\n| 3834 | def             | cdp            | doctors      | id                    | int         |                  |\n| 3835 | def             | cdp            | doctors      | ignoreCredentialing   | varchar     |                  |\n| 3836 | def             | cdp            | doctors       ...
# LLM Response: -- intermediate_sql
# SELECT DISTINCT dentistType FROM cdp.doctors;
# Extracted SQL: SELECT DISTINCT dentistType FROM cdp.doctors;
# Running Intermediate SQL: SELECT DISTINCT dentistType FROM cdp.doctors;
# Final SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Additional Context \n\nOur business is a dental company which focus on patient care, wit information on doctors, which are General Dentist, Orthodontist, Oral Surgeon, Pediatric Dentist, Hygienist. And we have branches at different locations. So we track the information of the patients how much they paid and who was the doctor who served them. It also have a list of potential patients and there medical aid there are using. The company is located in USA texas\n\nThe following columns are in the doctors table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME   | COLUMN_NAME           | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:-------------|:----------------------|:------------|:-----------------|\n| 3811 | def             | cdp            | doctors      | abbr                  | varchar     |                  |\n| 3812 | def             | cdp            | doctors      | address               | varchar     |                  |\n| 3813 | def             | cdp            | doctors      | canManage             | varchar     |                  |\n| 3814 | def             | cdp            | doctors      | canWork               | varchar     |                  |\n| 3815 | def             | cdp            | doctors      | contractEnd           | varchar     |                  |\n| 3816 | def             | cdp            | doctors      | contractStart         | varchar     |                  |\n| 3817 | def             | cdp            | doctors      | createdAt             | datetime    |                  |\n| 3818 | def             | cdp            | doctors      | createdBy             | int         |                  |\n| 3819 | def             | cdp            | doctors      | credentialingDocs     | tinyint     |                  |\n| 3820 | def             | cdp            | doctors      | dateOfBirth           | datetime    |                  |\n| 3821 | def             | cdp            | doctors      | defaultPage           | varchar     |                  |\n| 3822 | def             | cdp            | doctors      | dentistShiftSpecialty | varchar     |                  |\n| 3823 | def             | cdp            | doctors      | dentistShiftType      | varchar     |                  |\n| 3824 | def             | cdp            | doctors      | dentistSubType        | varchar     |                  |\n| 3825 | def             | cdp            | doctors      | dentistType           | varchar     |                  |\n| 3826 | def             | cdp            | doctors      | dentistWorkTimeType   | varchar     |                  |\n| 3827 | def             | cdp            | doctors      | docEmail              | varchar     |                  |\n| 3828 | def             | cdp            | doctors      | docMobile             | varchar     |                  |\n| 3829 | def             | cdp            | doctors      | firstName             | varchar     |                  |\n| 3830 | def             | cdp            | doctors      | gender                | varchar     |                  |\n| 3831 | def             | cdp            | doctors      | hideUsage             | tinyint     |                  |\n| 3832 | def             | cdp            | doctors      | hireDate              | varchar     |                  |\n| 3833 | def             | cdp            | doctors      | homeLocation          | varchar     |                  |\n| 3834 | def             | cdp            | doctors      | id                    | int         |                  |\n| 3835 | def             | cdp            | doctors      | ignoreCredentialing   | varchar     |                  |\n| 3836 | def             | cdp            | doctors ...
# LLM Response: SELECT DISTINCT dentistType FROM cdp.doctors;
# Extracted SQL: SELECT DISTINCT dentistType FROM cdp.doctors;
# SELECT DISTINCT dentistType FROM cdp.doctors;
#                   dentistType
# 0                        None
# 1                     General
# 2                       Ortho
# 3                Oral Surgery
# 4  General;Ortho;Oral Surgery
# 5        General;Oral Surgery
# 6                  Hygienists
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28f6c2e4-7cdc-45db-bbbb-b90bf3a1326b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28f6c2e4-7cdc-45db-bbbb-b90bf3a1326b")) {                    Plotly.newPlot(                        "28f6c2e4-7cdc-45db-bbbb-b90bf3a1326b",                        [{"alignmentgroup":"True","hovertemplate":"Doctor Type=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[null,"General","Ortho","Oral Surgery","General;Ortho;Oral Surgery","General;Oral Surgery","Hygienists"],"xaxis":"x","y":[0,1,2,3,4,5,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automa ...
# ('SELECT DISTINCT dentistType FROM cdp.doctors;',
#                    dentistType
#  0                        None
#  1                     General
#  2                       Ortho
#  3                Oral Surgery
#  4  General;Ortho;Oral Surgery
#  5        General;Oral Surgery
#  6                  Hygienists,
#  Figure({
#      'data': [{'alignmentgroup': 'True',
#                'hovertemplate': 'Doctor Type=%{x}<br>index=%{y}<extra></extra>',
#                'legendgroup': '',
#                'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#                'name': '',
#                'offsetgroup': '',
#                'orientation': 'v',
#                'showlegend': False,
#                'textposition': 'auto',
#                'type': 'bar',
#                'x': array([None, 'General', 'Ortho', 'Oral Surgery', 'General;Ortho;Oral Surgery',
#                            'General;Oral Surgery', 'Hygienists'], dtype=object),
#                'xaxis': 'x',
#                'y': array([0, 1, 2, 3, 4, 5, 6]),
#                'yaxis': 'y'}],
#      'layout': {'barmode': 'relative',
#                 'legend': {'tracegroupgap': 0},
#                 'template': '...',
#                 'title': {'text': 'Doctor Types'},
#                 'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Doctor Type'}},
#                 'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'index'}}}
#  }))

# %% [markdown]
# ## Launch the User Interface
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn)
app.run()
# Out:
# Google Colab doesn't support running websocket servers. Disabling debug mode.
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.
# Your app is running at:
# https://8084-m-s-1fa9sl60acnya-d.us-east1-1.prod.colab.dev
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: off
# Info: None
# None
# SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Additional Context \n\nOur business is a dental company which focus on patient care, wit information on doctors, which are General Dentist, Orthodontist, Oral Surgeon, Pediatric Dentist, Hygienist. And we have branches at different locations. So we track the information of the patients how much they paid and who was the doctor who served them. It also have a list of potential patients and there medical aid there are using. The company is located in USA texas\n\nThe following columns are in the doctors table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME   | COLUMN_NAME           | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:-------------|:----------------------|:------------|:-----------------|\n| 3811 | def             | cdp            | doctors      | abbr                  | varchar     |                  |\n| 3812 | def             | cdp            | doctors      | address               | varchar     |                  |\n| 3813 | def             | cdp            | doctors      | canManage             | varchar     |                  |\n| 3814 | def             | cdp            | doctors      | canWork               | varchar     |                  |\n| 3815 | def             | cdp            | doctors      | contractEnd           | varchar     |                  |\n| 3816 | def             | cdp            | doctors      | contractStart         | varchar     |                  |\n| 3817 | def             | cdp            | doctors      | createdAt             | datetime    |                  |\n| 3818 | def             | cdp            | doctors      | createdBy             | int         |                  |\n| 3819 | def             | cdp            | doctors      | credentialingDocs     | tinyint     |                  |\n| 3820 | def             | cdp            | doctors      | dateOfBirth           | datetime    |                  |\n| 3821 | def             | cdp            | doctors      | defaultPage           | varchar     |                  |\n| 3822 | def             | cdp            | doctors      | dentistShiftSpecialty | varchar     |                  |\n| 3823 | def             | cdp            | doctors      | dentistShiftType      | varchar     |                  |\n| 3824 | def             | cdp            | doctors      | dentistSubType        | varchar     |                  |\n| 3825 | def             | cdp            | doctors      | dentistType           | varchar     |                  |\n| 3826 | def             | cdp            | doctors      | dentistWorkTimeType   | varchar     |                  |\n| 3827 | def             | cdp            | doctors      | docEmail              | varchar     |                  |\n| 3828 | def             | cdp            | doctors      | docMobile             | varchar     |                  |\n| 3829 | def             | cdp            | doctors      | firstName             | varchar     |                  |\n| 3830 | def             | cdp            | doctors      | gender                | varchar     |                  |\n| 3831 | def             | cdp            | doctors      | hideUsage             | tinyint     |                  |\n| 3832 | def             | cdp            | doctors      | hireDate              | varchar     |                  |\n| 3833 | def             | cdp            | doctors      | homeLocation          | varchar     |                  |\n| 3834 | def             | cdp            | doctors      | id                    | int         |                  |\n| 3835 | def             | cdp            | doctors      | ignoreCredentialing   | varchar     |                  |\n| 3836 | def             | cdp            | doctors       ...
# LLM Response: -- intermediate_sql
# SELECT DISTINCT dentistType FROM cdp.doctors;
# Info: []
# []
# Info: None
# None
# SQL Prompt: [{'role': 'system', 'content': "You are a SQL expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Additional Context \n\nThe following columns are in the dbdetails table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME   | COLUMN_NAME   | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:-------------|:--------------|:------------|:-----------------|\n| 1172 | def             | cdp            | dbdetails    | createdAt     | datetime    |                  |\n| 1173 | def             | cdp            | dbdetails    | dataKey       | varchar     |                  |\n| 1174 | def             | cdp            | dbdetails    | dataValue     | varchar     |                  |\n| 1175 | def             | cdp            | dbdetails    | id            | int         |                  |\n| 1176 | def             | cdp            | dbdetails    | practice      | varchar     |                  |\n| 1177 | def             | cdp            | dbdetails    | updatedAt     | datetime    |                  |\n\nThe following columns are in the xray_audit_questions table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME           | COLUMN_NAME   | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:---------------------|:--------------|:------------|:-----------------|\n| 3197 | def             | cdp            | xray_audit_questions | createdAt     | datetime    |                  |\n| 3198 | def             | cdp            | xray_audit_questions | id            | int         |                  |\n| 3199 | def             | cdp            | xray_audit_questions | question      | text        |                  |\n| 3200 | def             | cdp            | xray_audit_questions | questionNo    | int         |                  |\n| 3201 | def             | cdp            | xray_audit_questions | setupId       | int         |                  |\n| 3202 | def             | cdp            | xray_audit_questions | updatedAt     | datetime    |                  |\n\nThe following columns are in the scheduleactivity table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME       | COLUMN_NAME     | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:-----------------|:----------------|:------------|:-----------------|\n| 2496 | def             | cdp            | scheduleactivity | createdAt       | datetime    |                  |\n| 2497 | def             | cdp            | scheduleactivity | id              | int         |                  |\n| 2498 | def             | cdp            | scheduleactivity | scheduleData    | text        |                  |\n| 2499 | def             | cdp            | scheduleactivity | scheduleId      | int         |                  |\n| 2500 | def             | cdp            | scheduleactivity | status          | int         |                  |\n| 2501 | def             | cdp            | scheduleactivity | updatedAt       | datetime    |                  |\n| 2502 | def             | cdp            | scheduleactivity | updatedSchedule | text        |                  |\n| 2503 | def             | cdp            | scheduleactivity | userId          | int         |                  |\n\nThe following columns are in the financialnotecategories table in the def database:\n\n|      | TABLE_CATALOG   | TABLE_SCHEMA   | TABLE_NAME              | COLUMN_NAME   | DATA_TYPE   | COLUMN_COMMENT   |\n|-----:|:----------------|:---------------|:------------------------|:--------------|:------------|:-----------------|\n| 1400 | def             | cdp            | financialnotecategories | id            | int         |                  |\n| 1401 | def             | cdp            | financialnotecategories | isDeleted    ...
# LLM Response: SELECT * FROM cdp.ppo_details WHERE expiry > CURRENT_DATE;
# Extracted SQL: SELECT * FROM cdp.ppo_details WHERE expiry > CURRENT_DATE;

# %% [markdown]
# ## Next Steps
# Using Vanna via Jupyter notebooks is great for getting started but check out additional customizable interfaces like the
# - [Streamlit app](https://github.com/vanna-ai/vanna-streamlit)
# - [Flask app](https://github.com/vanna-ai/vanna-flask)
# - [Slackbot](https://github.com/vanna-ai/vanna-slack)
